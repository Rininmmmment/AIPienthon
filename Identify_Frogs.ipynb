# %%
#ドライブのマウント
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/'My Drive'/'WebAppTest'

# !pip install streamlit
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/WebAppTest
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 9.2 MB 3.4 MB/s
# ...
#      |████████████████████████████████| 78 kB 5.5 MB/s
# ...
#      |████████████████████████████████| 4.7 MB 38.4 MB/s
# ...
#      |████████████████████████████████| 164 kB 61.5 MB/s
# ...
#      |████████████████████████████████| 181 kB 63.3 MB/s
# ...
#      |████████████████████████████████| 235 kB 58.4 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 51 kB 6.7 MB/s
# ...
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19582 sha256=0ff6403ea9884d2388640061cf15a7dab833e491f0d356e83ccf245249d8fd27
#   Stored in directory: /root/.cache/pip/wheels/5f/55/ab/36a76989f7f88d9ca7b1f68da6d94252bb6a8d6ad4f18e04e9
# Successfully built validators
# ...

# %%
#streamlitを起動する(your urlでサイトが表示される)
# !streamlit run app2.py & sleep 3 && npx localtunnel --port 8501
# Out:
# 2022-09-25 22:10:13.149 INFO    numexpr.utils: NumExpr defaulting to 2 threads.
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.2:8501
#   External URL: http://35.227.124.148:8501
#
# npx: installed 22 in 3.749s
# your url is: https://shaggy-planets-return-35-227-124-148.loca.lt
# 2022-09-25 22:10:33.707253: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Found 1 images belonging to 1 classes.
# Found 0 images belonging to 0 classes.
# 2022-09-25 22:12:51.398 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 562, in _run_script
#     exec(code, module.__dict__)
#   File "/content/drive/MyDrive/WebAppTest/app2.py", line 94, in <module>
# ...
